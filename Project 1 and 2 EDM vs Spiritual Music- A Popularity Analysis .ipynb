# %%
import pandas as pd
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
# Look only at tracks that mention "edm" or "spiritual" in their genre
edm_df = df[df["track_genre"].str.contains("edm|spiritual", case=False, na=False)]

# See the first 5 rows
edm_df.head()
# Out:
#        Unnamed: 0                track_id                  artists  \
# 30000       30000  7BKLCZ1jbUBVqRi2FVlTVw  The Chainsmokers;Halsey
# 30001       30001  0lYBSQXN6rCTvUZvg9S0lU   DJ Snake;Justin Bieber
# 30002       30002  0Cy7wt6IlRfBPHXXjmZbcP           Ellie Goulding
# 30003       30003  4uUG5RXrOk84mYEfFvj3cK  David Guetta;Bebe Rexha
# 30004       30004  7tbzfR8ZvZzJEzy6v0d6el                   Ritviz
#
#                                               album_name           track_name  \
# 30000                                             Closer               Closer
# 30001                                             Encore      Let Me Love You
# 30002  Fifty Shades Freed (Original Motion Picture So...  Love Me Like You Do
# 30003                                    I'm Good (Blue)      I'm Good (Blue)
# 30004                                                Dev                Liggi
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(edm_df["danceability"], edm_df["energy"], alpha=0.3, color="purple")
plt.xlabel("Danceability")
plt.ylabel("Energy")
plt.title("EDM & Spiritual Tracks: Danceability vs Energy")
plt.grid(True)
plt.show()

# %%
top_tracks = edm_df.sort_values(by="popularity", ascending=False).head(10)
top_tracks[["track_name", "artists", "popularity"]]
# Out:
#                                            track_name  \
# 30003                                 I'm Good (Blue)
# 30123                               Where Are You Now
# 30102                                            Numb
# 30120                                    Belly Dancer
# 30010                                      The Nights
# 30114                                       The Motto
# 30059                                      Wake Me Up
# 30052  Leave Before You Love Me (with Jonas Brothers)
# 30011                        Something Just Like This
# 30365                      Words (feat. Zara Larsson)
#
#                             artists  popularity
# 30003       David Guetta;Bebe Rexha          98
# 30123  Lost Frequencies;Calum Scott          88
# 30102             Marshmello;Khalid          87
# 30120                  Imanbek;BYOR          87
# 30010                        Avicii          86
# 30114                Tiësto;Ava Max          86
# ...

# %%
edm_df.groupby("track_genre")["popularity"].mean().sort_values(ascending=False)
# Out:
# track_genre
# edm    35.032
# Name: popularity, dtype: float64

# %%
# Group by genre and calculate average popularity
genre_popularity = edm_df.groupby("track_genre")["popularity"].mean().sort_values(ascending=False)

# Peek at it
genre_popularity.head(10)
# Out:
# track_genre
# edm    35.032
# Name: popularity, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
genre_popularity.plot(kind='bar', color='orange', edgecolor='black')

plt.title("Average Popularity by Genre (EDM & Spiritual Tracks)")
plt.xlabel("track_Genre")
plt.ylabel("Average Popularity")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
bars = plt.bar(genre_popularity.index, genre_popularity.values, color='skyblue', edgecolor='black')

plt.title("Average Popularity by Genre (EDM & Spiritual Tracks)")
plt.xlabel("track_Genre")
plt.ylabel("Average Popularity")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add text labels above bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Focus on genres you're interested in
target_genres = ["edm", "spiritual", "house", "trance", "meditation"]
mask = df["track_genre"].str.contains("|".join(target_genres), case=False, na=False)
music_df = df[mask].copy()

# Preview it
music_df.head()
# Out:
#        Unnamed: 0                track_id                     artists  \
# 13000       13000  4IlqQhaxrGPxmg35YcXXuS     Aaron Smith;Luvli;Krono
# 13001       13001  6WkJ2OK163XXS2oARUC9JM     Aaron Smith;Krono;Luvli
# 13002       13002  4h4AEqy0iBbjdlbtWvIx5O                Paul Johnson
# 13003       13003  3YXIVMQLRRq2K7kxC7UYx6  Marshall Jefferson;Solardo
# 13004       13004  1E8hMeQvfgvQPjN3BZ2viF                 Mr. Fingers
#
#                                album_name                          track_name  \
# 13000                          Ibiza 2019                Dancin - Krono Remix
# 13001  Dancin (feat. Luvli) [Krono Remix]  Dancin (feat. Luvli) - Krono Remix
# 13002                        Get Get Down                        Get Get Down
# 13003                      Move Your Body                      Move Your Body
# 13004                             Amnesia                     Mystery of Love
#
# ...

# %%
# Group by genre and calculate averages
genre_features = music_df.groupby("track_genre")[["danceability", "energy", "valence", "tempo"]].mean().sort_values("danceability", ascending=False)

# View the summary
genre_features
# Out:
#                    danceability    energy   valence       tempo
# track_genre
# chicago-house          0.766176  0.733215  0.586541  123.922680
# deep-house             0.710448  0.741855  0.447282  120.874904
# house                  0.668534  0.755083  0.494675  121.106951
# edm                    0.648220  0.756196  0.465198  122.037299
# progressive-house      0.623935  0.813359  0.365300  125.093636
# trance                 0.583409  0.845272  0.276881  133.276726

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

# Plot all three features
genre_features[["danceability", "energy", "valence"]].plot(kind="bar", figsize=(12,6), colormap="plasma")

plt.title("💃 Musical Characteristics by Genre (EDM & Spiritual)")
plt.xlabel("Genre")
plt.ylabel("Average Value")
plt.xticks(rotation=45, ha="right")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\surat\AppData\Local\Temp\ipykernel_10948\4042331661.py:14: UserWarning: Glyph 128131 (\N{DANCER}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\surat\anaconda3\envs\karmonic-music\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128131 (\N{DANCER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,6))
for genre in music_df["track_genre"].unique():
    genre_data = music_df[music_df["track_genre"] == genre]
    plt.scatter(genre_data["energy"], genre_data["valence"], label=genre, alpha=0.4)

plt.title("🧠 Energy vs Valence — How Music Feels")
plt.xlabel("Energy")
plt.ylabel("Valence (Happiness)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\surat\AppData\Local\Temp\ipykernel_10948\3009387857.py:11: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\surat\anaconda3\envs\karmonic-music\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
